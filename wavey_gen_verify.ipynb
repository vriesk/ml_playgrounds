# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import wavey_gen

RNG = np.random.default_rng(seed=123456789)

# %%
a = np.load("data/b_042.npy")

plt.rcParams["figure.figsize"] = (15,15)

plt.subplot(411)
plt.plot(a[0])
plt.subplot(412)
plt.plot(a[1])
plt.subplot(413)
plt.plot(a[10])
plt.subplot(414)
plt.plot(a[16])
plt.show()
